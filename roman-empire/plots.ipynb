# %%
import sys
from pathlib import Path
notebook_dir = Path().resolve()
ROOT = notebook_dir.parent
sys.path.append(str(ROOT))

from src.plotting import display_result_tables,plot_accs_bar_with_singe_embs,plot_loss_vs_acc_per_encoder,plot_loss_per_encoder
import torch

all_losses=torch.load(Path("/Users/emely/Uni/Thesis/Thesis/roman-empire/results/loss_histories.pt"))
other_accs=torch.load(Path("/Users/emely/Uni/Thesis/Thesis/roman-empire/results/best_acc_node_pos.pt"))
all_embeddings = torch.load(Path("/Users/emely/Uni/Thesis/Thesis/roman-empire/results/embeddings.pt"))
accs = torch.load(Path("/Users/emely/Uni/Thesis/Thesis/roman-empire/results/best_accs.pt"))
svm_results = torch.load(Path("/Users/emely/Uni/Thesis/Thesis/roman-empire/results/svm_results.pt"))
svm_results_node_pos = torch.load(Path("/Users/emely/Uni/Thesis/Thesis/roman-empire/results/svm_results_node_pos.pt"))

encoders = ['gcn', 'sage', 'gat', 'gin']
modes= ['Rand-Rewire', 'Rand-Aug', 'DP-Rewire', 'DP-Aug']

# %%
display_result_tables(accs, svm_results, other_accs, svm_results_node_pos)
# Out:
# ## MLP Results
# <style type="text/css">
# #T_7989d_row0_col1, #T_7989d_row0_col3, #T_7989d_row0_col4, #T_7989d_row2_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_7989d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7989d_level0_col0" class="col_heading level0 col0" >Mode</th>
#       <th id="T_7989d_level0_col1" class="col_heading level0 col1" >gcn</th>
#       <th id="T_7989d_level0_col2" class="col_heading level0 col2" >sage</th>
#       <th id="T_7989d_level0_col3" class="col_heading level0 col3" >gat</th>
#       <th id="T_7989d_level0_col4" class="col_heading level0 col4" >gin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7989d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7989d_row0_col0" class="data row0 col0" >Rand-Rewire</td>
#       <td id="T_7989d_row0_col1" class="data row0 col1" >0.959 ± 0.003</td>
# ...

# %%
plot_loss_per_encoder(all_losses)

# %%
plot_accs_bar_with_singe_embs(other_accs,modes,encoders,accs)

# %%
plot_loss_vs_acc_per_encoder(encoders,all_losses,accs)
# Out:
# /Users/emely/Uni/Thesis/Thesis/src/plotting.py:183: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   loss_curve = torch.tensor(all_losses[mode][enc])
# /Users/emely/Uni/Thesis/Thesis/src/plotting.py:183: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   loss_curve = torch.tensor(all_losses[mode][enc])
# /Users/emely/Uni/Thesis/Thesis/src/plotting.py:183: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   loss_curve = torch.tensor(all_losses[mode][enc])
# ...
